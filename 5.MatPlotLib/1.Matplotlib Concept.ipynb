# %% [markdown]
# # Matplotlib Overview Lecture

# %% [markdown]
# # Introduction

# %% [markdown]
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
# Generally easy to get started for simple plots
# Support for custom labels and texts
# Great control of every element in a figure
# High-quality output in many formats
# Very customizable in general
# Matplotlib allows you to create reproducible figures programmatically. Let's learn how to use it! Before continuing this lecture, I encourage you just to explore the official Matplotlib web page: http://matplotlib.org/

# %% [markdown]
# # Importing
# Import the matplotlib.pyplot module under the name plt (the tidy way):

# %%
import matplotlib.pyplot as plt

# %%
# inline function will allow us to see the plots created inside the jupyter notebook
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# There are two ways we can create the matplot:
# ->Functional ways
# ->object oriented ways

# %% [markdown]
# # Functional Method

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# # # Creating multiple plot in single Canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# # Object Oriented Method

# %%
fig = plt.figure()
# Now this has created the blank plot with 0 Axes

# %%
fig = plt.figure()
#                    [left of the axis,bottom of the axis,width,height]
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.5,0.15,0.4,0.3])

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)

axes2.plot(y,x)

# %% [markdown]
# SETTING TITLE

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %% [markdown]
# # Subplot in single canvas

# %%
fig,axes = plt.subplots()

axes.plot(x,y)

# %%
# Creating two columns with single rows
fig,axes = plt.subplots(nrows=1,ncols=2)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)

# %% [markdown]
# Now to fix the above overlap

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)
plt.tight_layout()

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# NOTE:~ Axes is the array of matplotlib axes, so we can iterate through it

# %% [markdown]
# NOTE:~ axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
#        axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
#         The above two line code is done automatically by subplots, by assigning         the rows and columns value

# %% [markdown]
# # # Iterating through the axes

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
# Iterating through the axes
for current_ax in axes:
    current_ax.plot(x,y)

# %% [markdown]
# # # Indexing through the axes

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[1].plot(y,x)

# %% [markdown]
# # # Figure size and DPI

# %%
# dpi-> Dots per inch / pixel per inch

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %% [markdown]
# # ## subplots

# %%
# Not specifying rows and columns

# %%
fig,axes = plt.subplots(figsize=(8,2))

axes.plot(x,y)

# %%
# Specifying rows and columns

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %% [markdown]
# # # Saving Figures

# %%
fig

# %%
fig.savefig('my_picture.png',dpi=200)

# %% [markdown]
# # # Legend FUNCTION
#
# LEGEND FUNCTION WILL CLERIFY WHAT PLOT IS WHAT PLOT

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title('Title')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2)
ax.plot(x,x**3)

# %% [markdown]
# NOTE:~ NOW WE WILL GET CONFUSE THAT WHICH PLOT REPRESENT WHAT? SO HERE COMES THE LEGEND FUNCTION

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='x square')
ax.plot(x,x**3,label='x cube')
ax.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='x square')
ax.plot(x,x**3,label='x cube')
ax.legend(loc=0) # loc=0 will find the best place to be placed the legend box.

# %% [markdown]
# # # Setting color

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)

# %%
# Setting color
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='orange')

# %%
# Setting color
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='#FF8C00') # RGB Hex Code

# %% [markdown]
# # # Line widths and Line Style

# %%
# Setting width
# Default linewidth is 1
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=2)

# %% [markdown]
# alpaha: will give the transparancy to the line

# %%
# Without alpha
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=3)

# %%
# With alpha
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=3,alpha=0.5)

# %% [markdown]
# # ## Line Style

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=3,linestyle='--')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=3,linestyle='-.')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=3,linestyle=':')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='-')

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x)
# Out:
# 11

# %% [markdown]
# # ## Marker

# %% [markdown]
# Now, marker will point to each and every data present, in our case it's is 11

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='-',marker='o',markersize=5)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='-',marker='*',markersize=10)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='-',marker='1',markersize=10)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='-',marker='o',markersize=20,
       markerfacecolor='yellow')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='-',marker='o',markersize=20,
       markerfacecolor='yellow',markeredgewidth=3)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='-',marker='o',markersize=20,
       markerfacecolor='yellow',markeredgewidth=3,markeredgecolor='green')

# %% [markdown]
# # ## Control over axis apperance

# %% [markdown]
# In this section we will look at controlling axis sizing properties in a matplotlib figure.

# %% [markdown]
# # Plot Range

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=2,linestyle='--')

# %% [markdown]
# Suppose if we want to show only the plot between the 0 and 1 in x axis, then:

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=2,linestyle='--')
ax.set_xlim([0,1])
# Out:
# (0.0, 1.0)

# %%
# Similarly doing for both x and y
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=2,linestyle='--')
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)
